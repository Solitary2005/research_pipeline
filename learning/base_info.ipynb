# %% [markdown]
# # Harness

# %% [markdown]
# 1. Harness engineering 是给模型搭建一套工作制度，以约束LLM
# 2. Harness 的关键功能：
#     - planner：拆解任务
#     - memory：告诉失忆的工程师和是的上下文（如任务目标，任务进展）
#     - evaluator：验证工程师的工作质量
#     - corrector：当工程师做的不好时，纠正错误
#     - constraint：约束工程师的行为，不进行危险的操作
#     - evolution：将工程师的成功经验固化下来供以后使用r5
